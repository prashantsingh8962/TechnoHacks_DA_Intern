# %% [markdown]
# # Task 1 - Perform Data Cleaning

# %% [markdown]
# ### We have titanic dataset for this task. It consist of two tables Train and Test.

# %% [markdown]
# Clean the dataset by removing missing values and outliers.

# %% [markdown]
# ### Train table :

# %%
import pandas as pd

# %%
# reading train table
df1= pd.read_csv("C:\\Users\\Prashant Singh\\OneDrive\\Documents\\Internships\\TechnoHacks\\train.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# check null values
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill missing values in 'Age' with the median and reassign the column
df1['Age'] = df1['Age'].fillna(df1['Age'].median())

# Drop rows with missing values in the 'Embarked' column and reassign the DataFrame
df1 = df1.dropna(subset=['Embarked'])

# Drop the 'Cabin' column if it exists and reassign the DataFrame
df1 = df1.drop(columns=['Cabin'], errors='ignore')

df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# checking again null values is 0
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Find Outliers Using boxplot

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

# Plotting each column's boxplot
plt.subplot(3, 4, 1)
df1['PassengerId'].value_counts().plot(kind='box')
plt.xlabel('PassengerId')

plt.subplot(3,4,2)
df1['Survived'].value_counts().plot(kind = 'box')
plt.xlabel('Survived')

plt.subplot(3,4,3)
df1['Pclass'].value_counts().plot(kind = 'box')
plt.xlabel('Pclass')

plt.subplot(3,4,4)
df1['Name'].value_counts().plot(kind ='box')
plt.xlabel('Name')

plt.subplot(3,4,5)
df1['Sex'].value_counts().plot(kind = 'box')
plt.xlabel('Sex')

plt.subplot(3,4,6)
df1['Age'].value_counts().plot(kind ='box')
plt.xlabel('Age')

plt.subplot(3,4,7)
df1['SibSp'].value_counts().plot(kind='box')
plt.xlabel('SibSp')

plt.subplot(3,4,8)
df1['Parch'].value_counts().plot(kind ='box')
plt.xlabel('Parch')

plt.subplot(3,4,9)
df1['Ticket'].value_counts().plot(kind ='box')
plt.xlabel('Ticket')

plt.subplot(3,4,10)
df1['Fare'].value_counts().plot(kind= 'box')
plt.xlabel('Fare')

plt.subplot(3,4,11)
df1['Embarked'].value_counts().plot(kind = 'box')
plt.xlabel('Embarked')

# Adjust layout for better presentation
plt.tight_layout()
plt.show()

# %%
# removing outliers using IQR method
Q11 = df1['Fare'].quantile(0.25)
Q31 = df1['Fare'].quantile(0.75)
IQR1 = Q31-Q11
lower_bound1 = Q11-1.5*IQR1
upper_bound1 = Q31+1.5*IQR1
df1[(df1['Fare'] >= lower_bound1) & (df1['Fare'] <= upper_bound1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male  28.0      0      0
# ...

# %% [markdown]
# ### Test table :

# %%
# reading Test table
df2= pd.read_csv("C:\\Users\\Prashant Singh\\OneDrive\\Documents\\Internships\\TechnoHacks\\test.csv")
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# check null values
df2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Fill missing values in 'Age' with the median and reassign the column
df2['Age'] = df2['Age'].fillna(df1['Age'].median())

# Drop rows with missing values in the 'Embarked' column and reassign the DataFrame
df2 = df2.dropna(subset=['Fare'])

# Drop the 'Cabin' column if it exists and reassign the DataFrame
df2 = df2.drop(columns=['Cabin'], errors='ignore')

df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
# checking again null values is 0
df2.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# remove duplicates If had
df2.drop_duplicates(inplace = True)
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
# check outliers using boxplot


# Adjust figure size
plt.figure(figsize=(10, 8))

# Plotting each column's boxplot
plt.subplot(3, 4, 1)
df2['PassengerId'].value_counts().plot(kind='box')
plt.xlabel('PassengerId')

plt.subplot(3, 4, 2)
df2['Pclass'].value_counts().plot(kind ='box')
plt.xlabel('Pclass')

plt.subplot(3, 4, 3)
df2['Name'].value_counts().plot(kind='box')
plt.xlabel('Name')

plt.subplot(3, 4, 4)
df2['Sex'].value_counts().plot(kind ='box')
plt.xlabel('Sex')

plt.subplot(3, 4, 5)
df2['Age'].value_counts().plot(kind='box')
plt.xlabel('Age')

plt.subplot(3, 4, 6)
df2['SibSp'].value_counts().plot(kind='box')
plt.xlabel('SibSp')

plt.subplot(3, 4, 7)
df2['Parch'].value_counts().plot(kind='box')
plt.xlabel('Parch')

plt.subplot(3, 4, 8)
df2['Ticket'].value_counts().plot(kind='box')
plt.xlabel('Ticket')

plt.subplot(3, 4, 9)
df2['Fare'].value_counts().plot(kind ='box')
plt.xlabel('Fare')

plt.subplot(3, 4, 10)
df2['Embarked'].value_counts().plot(kind='box')
plt.xlabel('Embarked')

# Adjust layout for better presentation
plt.tight_layout()
plt.show()

# %%
# removing outliers using IQR method

Q1 = df2['Fare'].quantile(0.25)
Q3 = df2['Fare'].quantile(0.75)
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
df2[(df2['Fare'] >= lower_bound) & (df2['Fare'] <= upper_bound)]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Embarked
# ...
