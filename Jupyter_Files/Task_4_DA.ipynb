# %% [markdown]
# # Task 4 : Pivote Table

# %% [markdown]
# ## We have titanic dataset for this task. It consist of two tables Train and Test.

# %% [markdown]
# Use pivot tables to summarize data in a dataset

# %% [markdown]
# ## Train table :

# %%
import pandas as pd

# %%
# reading train table
df1= pd.read_csv("C:\\Users\\Prashant Singh\\OneDrive\\Documents\\Internships\\TechnoHacks\\train.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Average fare paid by passengers based on class and gender
pivot_table = df1.pivot_table(values='Fare', index='Pclass', columns='Sex', aggfunc='mean')
print(round(pivot_table,2))
# Out:
# Sex     female   male
# Pclass
# 1       106.13  67.23
# 2        21.97  19.74
# 3        16.12  12.66

# %%
# Average Survived paid by passengers based on class and gender
pivot_table = df1.pivot_table(values='Fare', index='Survived', columns='Sex', aggfunc='mean')
print(round(pivot_table,2))
# Out:
# Sex       female   male
# Survived
# 0          23.02  21.96
# 1          51.94  40.82

# %% [markdown]
# ## Test table :

# %%
# reading Test table
df2= pd.read_csv("C:\\Users\\Prashant Singh\\OneDrive\\Documents\\Internships\\TechnoHacks\\test.csv")
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# Average fare paid by passengers based on class and gender
pivot_table = df2.pivot_table(values='Fare', index='Pclass', columns='Sex', aggfunc='mean')
print(round(pivot_table,2))
# Out:
# Sex     female   male
# Pclass
# 1       115.59  75.59
# 2        26.44  20.18
# 3        13.74  11.83

# %%
# Average Embarked paid by passengers based on class and gender
pivot_table = df2.pivot_table(values='Fare', index='Embarked', columns='Sex', aggfunc='mean')
print(round(pivot_table,2))
# Out:
# Sex       female   male
# Embarked
# C          92.00  49.65
# Q          12.42   9.36
# S          40.72  22.16
